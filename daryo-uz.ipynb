# %% [markdown]
# <a href="https://www.kaggle.com/code/airiteam/daryo-uz?scriptVersionId=110313815" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/daryo-uz-yangiliklar/daryo_data.csv

# %%
data = pd.read_csv("/kaggle/input/daryo-uz-yangiliklar/daryo_data.csv")
data
# Out:
#                                                     title  \
# 0       Bayden Putinning “o‘ta og‘ir ahvolda” ekanligi...
# 1       Germaniya prezidenti xavfsizlik nuqtayi nazari...
# 2       Erdo‘g‘on Zelenskiyga “har qanday sharoitda ha...
# 3       Isroil Ukrainaga qurol bermaydi, ammo raketa h...
# 4       BMW AQSHda elektromobil ishlab chiqarishga 1,7...
# ...                                                   ...
# 175212  Shosse velosporti bo‘yicha O‘zbekiston chempio...
# 175213             Zidan “Real”ga bosh murabbiylik qiladi
# 175214  Toshkentda yaponiyalik karate ustasi Tanaka Ta...
# 175215  Toshkentdagi qilichbozlik musobaqasida OTMlarg...
# 175216  Server Jeparov Gonkongga qarshi o‘yinda asosiy...
#
#                                                   content target
# 0       AQSH prezidenti Jo Bayden 19-oktabr, chorshanb...  dunyo
# 1       Germaniya prezidenti Frank-Valter Shtaynmayer ...  dunyo
# 2       Turkiya prezidenti Rajab Toyyib Erdo‘g‘on Ukra...  dunyo
# 3       Isroil mudofaa vaziri Benni Gants 19-oktabr, c...  dunyo
# 4       Bugun, 19-oktabr kuni Germaniyaning BMW avtomo...  dunyo
# ...                                                   ...    ...
# 175212  Toshkent viloyatining Yangibozor shossesida 7—...  sport
# 175213  “Real” bosh murabbiyi yordamchisi Zayniddin Zi...  sport
# 175214  Toshkent geodeziya va kartografiya kasb-hunar ...  sport
# 175215  Toshkentda qilichbozlik bo‘yicha yoshlar o‘rta...  sport
# 175216  O’zbekiston milliy terma jamoasi bosh murabbiy...  sport
#
# [175217 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175217 entries, 0 to 175216
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   title    175217 non-null  object
#  1   content  174621 non-null  object
#  2   target   175217 non-null  object
# dtypes: object(3)
# memory usage: 4.0+ MB

# %%
data.describe()
# Out:
#                                                     title  \
# count                                              175217
# unique                                             165815
# top     O‘zbekistonda dollarning rasmiy kursi yana ko‘...
# freq                                                   61
#
#                                                   content    target
# count                                              174621    175217
# unique                                             166321         7
# top     Dunyo bo‘ylab olingan sara suratlarni taqdim e...  mahalliy
# freq                                                   84     73136

# %% [markdown]
# # Davomini yozamiz albatta, faqat sizlar shu datalar bilan ishlab chiqib, o'z variantlaringizni yozib qoldirishingiz kerak. Hammaga omad
